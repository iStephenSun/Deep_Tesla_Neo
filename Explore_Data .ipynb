# %% [markdown]
# # Prepare local env

# %%
# Import local env
import params
import preparedata



import cv2
import matplotlib.pyplot as plt
import pylab
import numpy as np 
import pandas as pd

# %% [markdown]
# # Raw Video  - Demo image

# %%
video_path = ".\epochs\epoch01_front.mkv"

cap = cv2.VideoCapture(video_path)
ret, img = cap.read()
cap.release()
## Show
plt.imshow(img)
pylab.show()

# %%
## The size of the images
img.shape
# Out:
# (720, 1280, 3)

# %% [markdown]
# # Processed Video - Demo image

# %%
# preprocess the data 
img = preparedata.preprocess(img)

## Show
plt.imshow(img)
pylab.show()

# %%
## The size of the images
img.shape
# Out:
# (66, 200, 3)

# %% [markdown]
# # Wheel Info

# %%
## Load wheel signal data
import pandas as pd


wheel_sig = pd.read_csv(".\epochs\epoch01_steering.csv")
## Show
wheel_sig.head()
# Out:
#            ts_micro  frame  wheel
# 0  1464650070285914      0   -1.0
# 1  1464650070319247      1   -1.0
# 2  1464650070352581      2   -1.0
# 3  1464650070385914      3   -1.0
# 4  1464650070419247      4   -1.0

# %%
## Distribution of wheel signal
wheel_sig.wheel.hist(bins=50)
pylab.show()
